# %% [markdown]
# ### V7. Consiga exactamente esta visualización utilizando los datos:
# ![visu.png](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

user_friends = pd.read_csv('/content/drive/MyDrive/Datos/TP1/Parte 1/user.csv', usecols=['friends'])
user_friends
# Out:
#                                                    friends
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...
# ...                                                    ...
# 1987892                                               None
# 1987893                                               None
# 1987894                                               None
# 1987895                                               None
# 1987896                                               None
#
# [1987897 rows x 1 columns]

# %% [markdown]
# Calculo la cantidad de amigos que tiene cada usuario:

# %%
def number_of_friends(friends):
  if friends == "None":
    return 0 
  return len(friends.split(','))

user_friends['number_of_friends'] = user_friends['friends'].map(number_of_friends)
user_friends
# Out:
#                                                    friends  number_of_friends
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...              14995
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...               4646
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...                381
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...                131
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...                 27
# ...                                                    ...                ...
# 1987892                                               None                  0
# 1987893                                               None                  0
# 1987894                                               None                  0
# 1987895                                               None                  0
# 1987896                                               None                  0
#
# [1987897 rows x 2 columns]

# %%
user_friends.number_of_friends.value_counts()
# Out:
# 0       878551
# 1       115103
# 2        57923
# 3        38827
# 4        30168
#          ...
# 2777         1
# 3572         1
# 2051         1
# 1551         1
# 3890         1
# Name: number_of_friends, Length: 2640, dtype: int64

# %% [markdown]
# Para obtener el mismo gráfico, me quedo solo con los usuarios que tienen entre 0 y 600 amigos:

# %%
user_friends = user_friends[user_friends['number_of_friends'] <= 600]
percentil_80 = user_friends['number_of_friends'].quantile(0.8)

# %% [markdown]
# Grafico la densidad de la cantidad de amigos y el cuantil 80 de la misma:

# %%
plt.figure(dpi=150)
sns.kdeplot(user_friends['number_of_friends'], color='#B7EA53', shade=True)
plt.xlim(0, 600)
plt.yticks([])
plt.title('Ley de potencias para la cantidad de amigos')
plt.ylabel('')
plt.xlabel('Cantidad de amigos')
plt.axvline(x=percentil_80, color='#DEA82A', label='Percentil 80', linestyle='--')
plt.legend()
plt.show()
